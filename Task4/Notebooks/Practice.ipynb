# %% [markdown]
# ## Some practice

# %%
import numpy as np
N = 100
fib = [0,1]

for i in range(2,N):
    next_number=fib[-1]+fib[-2]
    fib.append(next_number)

s = sum(fib[1::2])

for i in range(2,int(
