# %% [markdown]
# Answers for Week 1
# * Name: Wendy Oosterhof
# * Username: wroosterhof
# * Student s-number: S6328091
# * Group: AS6

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 #processed on Jupyter Hub

# %% [markdown]
# ![dolphin.png](attachment:bfd6b8d5-55fb-4738-b225-24057d290db1.png)

# %%
y = 6
y *=5
y *=4
y *=3
y *=2
y *=1
print("y:", y)
# Out:
# y: 720

# %%
from scipy.constants import h
print("h:", h)
f = 2.42e28
E = h * f
print("E:",E)
# Out:
# h: 6.62607015e-34
# E: 1.6035089763e-05

# %%
from scipy.constants import G

Mm = 7.342e22
Ms = 5.9722e24
r = 385000.6e3 #m

F = (G*Mm*Ms)/(r**2)

print("F:", F)
# Out:
# F: 1.974384051807571e+20

# %%
x1 = 10    #value one described
x2 = 22/7  #value of x2 described
print(x1, end="") #first value printed, but no space after
print(x2, end="") #second value printed right after the first one.
# Out:
# 103.142857142857143

# %% [markdown]
# ![Screenshot from 2026-02-12 14-12-58.png](attachment:08a1d5bc-c114-41e5-8cd6-67f12e6025a7.png)

# %% [markdown]
# the dot represents the current folder so in this case the PROGNUM folder.

# %% [markdown]
# ![Schermafbeelding 2026-02-12 134000.png](attachment:9c80bb40-7ad4-4ecd-88eb-3a1451931fd4.png)

# %% [markdown]
# 1.15

# %% [markdown]
# 1. the output of Unix command pwd is: /Users/users/wroosterhof/Downloads
# 2. The notation . refers to the current directory so the Downloads file, while the .. refers to the parent file, so wroosterhof

# %% [markdown]
# 1.16

# %% [markdown]
# cd ~/Desktop

# %% [markdown]
# 1.19
# 1. The command ls *[0-9]*.[co] makes an list including t1.c and t2.o.
# 2. The square brackets are required to match any single characters in parentheses. So in this case that would be 0-9 and c and o.
# 3. The command ls *[0-9]*.co shows a list of just t3.co, since that's the only one with a number 0-9 in it (cause of the *[0-9]* and also has a .co ending, while .[co] just implies either c OR o, not both in the specific order.

# %% [markdown]
# 1.20
# 1. it lists t1.c, t2.o, t3.co and t.c in this order.
# 2. When you press the arrow up key it fills in the past command in the konsole.
# 3. When you press arrow up after typing ls it fills in the last ls you have done in the konsole.
