# %% [markdown]
# # Coursework Set Week 2

# %% [markdown]
# **Common remarks**:
#
# * Deadline: Sunday at 23:59h for the week of this task
# * <font color='red'>Keep all the information in this template unaltered!</font>
#
# **Please fill in the following fields:**
#
# * Name: Wendy Oosterhof
# * Username: wroosterhof
# * Student number: S6328091
# * Group (AS1, etc.): AS6
#
# -----

# %%
totalpoints = currentpoints = 0

# %% [markdown]
# ### Julian Date, a algorithm with some pitfalls (4 pt) <font color='red'><b>COURSEWORK</b></font>
#
# In the online article: [A one-line algorithm for Julian Date](http://adsabs.harvard.edu/full/1983IAPPP..13...16F)
# we find an old and very compact formula for programmable calculators to calculate a Julian Date given a day, month and year.
# A Julian Date is in fact a
# day number corresponding to the number of elapsed days since the beginning of a cycle of 7980 years.
# That makes it a useful tool to calculate how many days there are between two dates.
# The one-line algorithm is valid for the period that started in 1582 with the Gregorian calendar.
# The formula from the article is:
#
#
# ``JD = 367*Y -7*(Y+(M+9)/12)/4 - 3*((Y+(M-9)/7)/100 + 1)/4 + (275*M)/9 + D + 1721029-0.5``
#
# The article notes: **It is important to note that after all divisions in this expression only that portion of the
# quotient to the left of the decimal point is retained and that the quotient is not rounded off.**
#
# * Use your notebook to develop an implementation of this formula.
# * Then create a Python script called ``JD.py`` that asks a user to enter day, month and year. For this date, the script calculates the Julian Date (JD) and prints it. The day can be entered as a floating point number to allow for fractional days.
# * The article provides a test case: the Julian Date for January 4, 1700 is 2341975.5.
#   Use your code to get the correct result, and attach your screen shot in this notebook.&nbsp;
#
# Extend the program on the notebook, so that it can calculate the number of days between two dates in the Gregorian calendar. What is your age expressed in days?
#
# **Answers**:

# %% [markdown]
# Githublink
# https://github.com/wendyr07/PROGNUM-repo.git

# %%
#!/usr/bin/env python
# coding: utf-8

# In[2]:


y = input("Do you want the difference between 2 dates, yes or no? ") #Choose whether you'd like to calculate one date or two dates.

D1 = float(input("Day: ")) #Fill in the first day, float so you can fill in decimal numbers.
M1 = int(input("Month: ")) #Fill in the first month.
Y1 = int(input("Year: "))  #Fill in the first year.

#Formula for the first date.
JD_1 = 367*Y1-7*(Y1+(M1+9)/12)/4-3*((Y1+(M1-9)/7)/100+1)/4+(275*M1)/9+D1+1721029-0.5
print(f"The first date as a Julian date is: {int(JD_1)} days.") #Printed as integer to keep the answer shorter.

#extension
if y == "yes": #If you put "yes" as the first one, you get a second date to fill.
    D2 = float(input("Day 2: ")) #Fill in the second day, float so you can fill in decimal numbers.
    M2 = int(input("Month 2: ")) #Fill in the second month.
    Y2 = int(input("Year 2: "))  #Fill in the second year.
    
    #Formula for the second date.
    JD_2 = 367*Y2-7*(Y2+(M2+9)/12)/4-3*((Y2+(M2-9)/7)/100+1)/4+(275*M2)/9+D2+1721029-0.5
    print(f"The second date as a Julian date is: {int(JD_2)} days.") #Printed as integer to keep the answer shorter.

    #Difference of the dates.
    JD_difference = abs(JD_2 - JD_1) #Takes the absolute of the equation, because of the possibility that the dates were filled in wrongly.
    print(f"The difference between the two dates in Julian date form is: {int(JD_difference)} days.") #Prints as an integer to keep the answer reasonably short (no decimals).


# In[ ]:

# %% [markdown]
# ![JD.png](attachment:c9a98377-00f3-431a-8a1e-ceb9d55899e8.png)

# %% [markdown]
# On the day of February 20, 2026, my age in Julian date form is 6740 days.

# %%
# Leave unaltered
totalpoints += 4
currentpoints += 0.0

# %% [markdown]
# ###  Calculating the roots of a second degree polynomial (3 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Use your notebook to develop the necessary code and then which solves for the roots
# of $f(x)=ax^2+bx+c$ for values of ``a``, ``b`` and ``c`` entered by a user of your program.
# All the required information related to this question is included in the notebook about conditions.
#
# You have to remember that
#
# $$f(x)=ax^2+bx+c$$
#
# has two solutions:
#
# $$x_1=\frac{-b + \sqrt{b^2-4ac}}{2a} \quad\text{and}\quad x_2=\frac{-b - \sqrt{b^2-4ac}}{2a}$$
#
# only if:
#
# $$\begin{split}D= b^2-4ac>0\end{split}$$
#
# It has one solution if $D == 0$ and no solutions (at least no real solutions) if $D < 0$.
#
# * Use the ``if,elif,else`` construct to print either two solutions, one solution or an message that no solutions
#  could be found.
# * Use f-strings for your output if there are solutions.
# * Include your code with an input example and its output in your notebook.
# * Use your notebook code to create a script called ``abc.py``.
# * On Terminal, run your python script, screenshot the result, and attach the it here.
#
# **Answer**:

# %%
from math import *
a = float(input("a for the ax^2: ")) #Float input for the a, since there could be decimals or negative numbers.An example: 1.
b = float(input("b for the bx: "))   #" ". An example: -9.
c = float(input("c for the c: "))    #" ". An example: 14.

D = b**2 - 4*a*c  #Calculates the discriminant.
print("The discriminant is: ", D)  #Prints the discriminant.

if D > 0:  #If D>0 there should be two solutions, so then calculate 2 solutions.
    x_1 = (-b + sqrt(D))/(2*a)  #Calculation solution 1
    x_2 = (-b - sqrt(D))/(2*a)  #Calculation solution 2
    print(f"There are 2 solutions: x_1 = {x_1} and x_2 = {x_2}")  #Prints the 2 solutions with an f string.
    #Example solutions: x_1 = 7.0 and x_2 = 2.0

elif D == 0:  #If D is not positive, but D is 0, there is 1 solution.
    x = (-b/(2*a))  #Said solution
    print(f"There is 1 solution: x = {x}") #Prints the solution

else:  #If D is neither positive nor 0, the value should be negative and there are no solutions.
    print(f"There are no solutions") #Prints the outcome of an negative discriminant (no solutions).

# %% [markdown]
# ![abc.png](attachment:e081a519-4b35-4360-bee2-5ce0f7dec5f3.png)

# %%
# Leave unaltered
totalpoints += 3
currentpoints += 0.0

# %% [markdown]
# ### Uniqueness in lists using the `set` object (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given two lists with a number of gamma ray bursts per night for two different periods
#
# ```python
#     night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
#     night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
# ```
#
# Use Python sequence type `set` to create a **list**:
#
# 1. with values that are both in `night1` and `night2`.
# 1. with values that are the difference between `night1` and `night2`.
# 1. with values that contains all items from both sets, duplicates are excluded.
# 1. after an update of `night1` by removing all its elements that are not available in `night2`.
#
# **Answers**:

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3] #Get the lists
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0] #" "

set1 = set(night1) #Makes the list night1 into set1 (also deletes duplicates due to the transformation).
set2 = set(night2) #Same as above but then for night 2.

#Intersection
b = set.intersection(set1, set2) #Finds the values that are in both lists and makes a set of those values (set: b).
print(f"These are the values that are in both night1 and night2: {list(b)}")

#Differences
a = set.difference(set1, set2) #Set of values from night 1 that are not in night 2
c = set.difference(set2, set1) #Set of values from night 2 that are not in night 1 (in this case 0)
d = set(list(a)+list(c))  #Combines both lists of differences.
print(f"These are the values that are in different night1 and night2: {list(d)}") #Prints the list

#All values, no duplicates
set3 = set1.union(set2) #Combines both sets.
print(f"The values from both sets without duplicates: {list(set3)}.") #Prints the combined set.

#Values night 1 removing all elements not available in night 2
f = set1 - (set.difference(set1, set2)) #Set of night 1 - the values of set 2, so only the values of night 1 that are also available in night 2 remain.
print(f"The values from night 1 without all elements not available in night 2: {list(f)}.") #Prints the result.

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0.0

# %% [markdown]
# ### Change a value in a dictionary (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given the Python dictionary:
#
# ```python
# planetsmass = { 'Mercury' : 0.33,
#                 'Venus'   : 4.87, 'Earth'   : 5.98,
#                 'Mars'    : 0.65, 'Jupiter' : 1900,
#                 'Saturn'  :  570, 'Uranus'  :  87,
#                 'Neptune' :  100, 'Pluto'   :  0.7 }
# ```
#
# 1. Extract from this dictionary a Python **list** with only the names of the objects.
# 1. Print the mass of Venus in Earth masses.
# 1. Remove Pluto from your dictionary.
# 1. Add Planet Nine with mass 29.3 to the dictionary.
# 1. Print the modified dictionary.
#
#
# **Answer**:

# %%
planetsmass = { 'Mercury' : 0.33,
                'Venus'   : 4.87, 'Earth'   : 5.98,
                'Mars'    : 0.65, 'Jupiter' : 1900,
                'Saturn'  :  570, 'Uranus'  :  87,
                'Neptune' :  100, 'Pluto'   :  0.7 }

planets = planetsmass.keys()  #Sets the variable planets to the "keys" of the dictionary, aka, the names of the planets.
masses = planetsmass.values() #Sets the variable masses to the "values" of the dictionary, aka, the masses given.
print("Planet names:", planets) #Prints all the planet names from the dictionary.

m_ve = planetsmass['Venus']/planetsmass['Earth'] #Takes the mass of Venus, deviding it by the mass of Earth to get the mass of Venus in Earth masses.
print(f"Mass of Venus is Earth masses: {m_ve} Earth masses.") #Prints the mass of Venus in Earth masses.

del planetsmass['Pluto'] #Deletes the planet Pluto.
planetsmass.update({'Nine':29.3}) #Adds the planet 'Nine'.
print(planetsmass) #Prints the altered dictionary.

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0.0

# %% [markdown]
# ### Apply NumPy functions to data (2pt) <font color='red'><b>COURSEWORK</b></font>
#
# * Create a NumPy array `x` with 100 angles in degrees between 0 and 360 degrees using ``np.linspace()``
# * Calculate the ``np.sinc(x)`` values of ``x``, with ``x`` in radians. The definition of the sinc function is:
#
#   $$\mathrm{sinc}(x) = \frac{\sin(\pi x)}{\pi x}$$
#
# * Print the first 10 values of the result.
#
# **Answer**

# %%
import numpy as np #Imports numpy with an alias np.

x = np.linspace(0, 360, 100) #Gives 100 angles from 0 to 360 degrees.
x_rad = x * np.pi / 180 #Turns the degrees into radians.
b = np.sinc(x_rad) #Calculates the np.sinc(x) of the angles.
print(b[:10]) #Prints the first 10 results.

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0.0

# %% [markdown]
# ## Finishing up
#
# **Please read the section about your report in the task documentation very carefully before submitting it to BrightSpace.**
#
# ------------

# %% [markdown]
# ## T.A. Grading

# %%
# Leave unaltered
taskgrade = round(10*currentpoints/totalpoints, 1) if totalpoints != 0 else 0
print(f"Total number of points: {totalpoints}. Student score: {currentpoints}.  Task Grade = {taskgrade}")
