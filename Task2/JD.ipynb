# %%
y = input("2 dates, yes or no")

D1 = float(input("Day"))
M1 = int(input("Month"))
Y1 = int(input("Year"))

#extension
if y == "yes":
    D2 = float(input("Day 2"))
    M2 = int(input("Month 2"))
    Y2 = int(input("Year 2"))

JD_1 = 367*Y1-7*(Y1+(M1+9)/12)/4-3*((Y1+(M1-9)/7)/100+1)/4+(275*M1)/9+D1+1721029-0.5
print(int(JD_1))

#extension
if y == "yes":
    JD_2 = 367*Y2-7*(Y2+(M2+9)/12)/4-3*((Y2+(M2-9)/7)/100+1)/4+(275*M2)/9+D2+1721029-0.5
    print(int(JD_2))

if y == "yes":
    JD_difference = abs(JD_2 - JD_1)
    print(int(JD_difference))
# Out:
# 2 dates, yes or no yes
# Day 6
# Month 9
# Year 2007
# Day 2 8
# Month 2 11
# Year 2 2007
# 2454347
# 2454410
# 62
